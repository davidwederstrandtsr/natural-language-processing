# %%
import pandas as pd
import os
from acquire import get_news_articles, get_articles_from_topic, get_article_text

from requests import get
from bs4 import BeautifulSoup

# %% [markdown]
# ### Exercise 1  CodeUp Blog Articles
#
# - Scrape the article text from the following pages:
#     - https://codeup.com/codeups-data-science-career-accelerator-is-here/
#     - https://codeup.com/data-science-myths/
#     - https://codeup.com/data-science-vs-data-analytics-whats-the-difference/
#     - https://codeup.com/10-tips-to-crush-it-at-the-sa-tech-job-fair/
#     - https://codeup.com/competitor-bootcamps-are-closing-is-the-model-in-danger/

# %%
sites = [
    'https://codeup.com/codeups-data-science-career-accelerator-is-here/',
    'https://codeup.com/data-science-myths/',
    'https://codeup.com/data-science-vs-data-analytics-whats-the-difference/',
    'https://codeup.com/10-tips-to-crush-it-at-the-sa-tech-job-fair/',
    'https://codeup.com/competitor-bootcamps-are-closing-is-the-model-in-danger/'   
]

# %%
articles = [{'title' : get_article_text(site)[0],
             'body'  : get_article_text(site)[1]} for site in sites]

# %%
pd.DataFrame(articles)
# Out:
#                                                title  \
# 0  Codeup’s Data Science Career Accelerator is He...
# 1                        Data Science Myths - Codeup
# 2  Data Science VS Data Analytics: What’s The Dif...
# 3  10 Tips to Crush It at the SA Tech Job Fair - ...
# 4  Competitor Bootcamps Are Closing. Is the Model...
#
#                                                 body
# 0  Codeup’s Data Science Career Accelerator is He...
# 1  Data Science MythsPosted on October 31, 2018In...
# 2  Data Science VS Data Analytics: What’s The Dif...
# 3  10 Tips to Crush It at the SA Tech Job FairPos...
# 4  Competitor Bootcamps Are Closing. Is the Model...

# %% [markdown]
# ### Exercise 2  News Articles
# - Scrape text from https://inshorts.com/
#     - Topics:
#         - Business
#         - Sports
#         - Technology
#         - Entertainment

# %%
urls = [
        "https://inshorts.com/en/read/business",
        "https://inshorts.com/en/read/sports",
        "https://inshorts.com/en/read/technology",
        "https://inshorts.com/en/read/entertainment"
    ]

# %%
news_df = get_news_articles(urls)

# %%
news_df
# Out:
#                                                 title  \
# 0   Twitter CEO donates $10M to project giving $1,...
# 1   India's economic growth seen at 1.2% in Q4 FY2...
# 2   Firm whose stock surged 1000% in 2020 starts h...
# 3   Nokia shuts plant in Tamil Nadu after some emp...
# 4   Glenmark to start clinical trial to test poten...
# ..                                                ...
# 95  Music composer Pritam's father dies aged 86 af...
# 96  I can feel you beside me - quiet, caring: Ajay...
# 97  I'm coming mom: Radhika Madan as she flies to ...
# 98  Actor Kiran Kumar tests -ve for COVID-19 after...
# 99  Suicide Squad director's cut release would be ...
#
#                                                  body       category  \
# 0   Twitter's billionaire CEO Jack Dorsey has dona...       business
# 1   India's economy is estimated to have grown at ...       business
# 2   US biotech company Novavax said it has started...       business
# ...
